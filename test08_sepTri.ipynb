# %%
from helpers import * 
from boundaries import *
from augment import *

# %% [markdown]
# ### simple st

# %%
G_st = st_graph()   
plot_just_planar(st_graph())
# Out:
# ic| 'planar'

# %%
b = Boundaries(G_st)
b.find_seperating_triangles()
# Out:
# [0, 1, 2]
# [0, 1, 3]
# [0, 3, 2]
# [1, 2, 3]
# [[0, 1, 2]]

# %% [markdown]
# ### nested st

# %%
new_edges = [(0,8), (8,2)]
G_st.add_edges_from(new_edges)
plot_just_planar(G_st)
# Out:
# ic| 'planar'

# %%
b1 = Boundaries(G_st)
b1.find_seperating_triangles()
# Out:
# [0, 1, 2]
# [0, 1, 3]
# [0, 2, 8]
# [0, 3, 2]
# [1, 2, 3]
# [[0, 1, 2], [0, 3, 2]]
