# %%
from helpers import * 
from boundaries import *
from augment import *
import random

# %% [markdown]
# ### simple st

# %%
G_st = st_graph()   
pos = plot_just_planar(st_graph())
# Out:
# ic| 'planar'

# %%
# augment graph 
a = Augment(G_st)
a.run_augment()
# Out:
# ic| cut_vertices: [7, 0]

# %%
pos = plot_just_planar(a.G_final);
# Out:
# ic| 'planar'

# %%
# number of STs
b = Boundaries(a.G_final)
sep_tris = b.find_seperating_triangles()
b.find_sep_triangle_targets()
# p = len(STs)
sep_tris
# Out:
# [SeperatingTriangle([0, 3, 2], 1, (2, 3))]

# %%
b.clean_up_sep_triangle()
# Out:
# ic| ix: 0, new_node: 8, len(self.G.nodes): 8
# ic| tri.target_edge: (2, 3)

# %%
plot_just_planar(b.G_nost, pos) # TODO embedding must stay the same => way this is drawn isnt automatically going to look planar.. for some reason not actually respecting pos.. 
# todo add planarity check ..
# Out:
# ic| 'planar'

# %%
a.seperating_triangle_check(b.G_nost)

# %%
b.find_boundary_points()
b.find_boundary_edges()

# %%
b.shortcuts # finding cips tricky w this embedding ..
# Out:
# [(4, 6), (1, 3), (4, 7)]

# %% [markdown]
# ### nested st

# %%
new_edges = [(0,8), (8,2)]
G_st2 = G_st.copy()
G_st2.add_edges_from(new_edges)
plot_just_planar(G_st2)
# Out:
# ic| 'planar'

# %%
b1 = Boundaries(G_st2)
b1.find_seperating_triangles()
# Out:
# [SeperatingTriangle([0, 1, 2], 3, None),
#  SeperatingTriangle([0, 1, 2], 8, None),
#  SeperatingTriangle([0, 3, 2], 8, None)]
