# %%
from helpers import * 
from boundaries import *
from augment import *
import random

# %% [markdown]
# ### simple st

# %%
G_st = st_graph()   
plot_just_planar(st_graph())
# Out:
# ic| 'planar'

# %%
class SeperatingTriangle:
    cycle:list = []
    inner_node:int = None

# %%
s = SeperatingTriangle
s.cycle = [0, 2,3]

# %%
s.cycle
# Out:
# [0, 2, 3]

# %%
list(G_st.edges)
# Out:
# [(0, 1),
#  (0, 3),
#  (0, 2),
#  (0, 7),
#  (1, 2),
#  (1, 3),
#  (2, 3),
#  (4, 5),
#  (4, 7),
#  (5, 6),
#  (6, 7)]

# %%
# number of STs
b = Boundaries(G_st)
sep_tris =b.find_seperating_triangles()
# p = len(STs)
sep_tris
# Out:
# [SeperatingTriangle([0, 1, 2], 3)]

# %%
b.find_sep_triangle_targets()
# Out:
# [(0, 1)]

# %%
sep_tris
# Out:
# [SeperatingTriangle([0, 1, 2], 3)]

# %%
# fix st algo - Roy 2001 
n = len(G_st.nodes) 
# will find a set of less than k edges that are needed to solve st problem  => here setting to n 
k = n
# holds jth edge of E of (G(V, E))
S = [0]*k

for i in range(k):
    j = random.randint(1, n)
    S[i] = list(G_st.edges)[j]
S
# Out:
# [(2, 3), (0, 3), (4, 5), (0, 7), (0, 7), (1, 2), (4, 5), (1, 3)]

# %%
all_edges = list(G_st.edges())
random.shuffle(all_edges)
sampled_edges = all_edges[:k]
sampled_edges
# Out:
# [(0, 2), (5, 6), (4, 7), (4, 5), (6, 7), (0, 1), (2, 3), (1, 3)]

# %% [markdown]
# ### nested st

# %%
new_edges = [(0,8), (8,2)]
G_st2 = G_st.copy()
G_st2.add_edges_from(new_edges)
plot_just_planar(G_st2)
# Out:
# ic| 'planar'

# %%
b1 = Boundaries(G_st2)
b1.find_seperating_triangles()
# Out:
# [[0, 1, 2], [0, 3, 2]]
