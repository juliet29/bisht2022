# %%
from imports import update_path
update_path()
import networkx as nx
from simple_four_con import graph_data

# %%
G = nx.binomial_tree(3)
nx.draw_networkx(G)

# %%
is_planar, embed = nx.check_planarity(G)
embed.get_data()
# Out:
# {0: [1, 2, 4],
#  1: [0],
#  2: [0, 3],
#  3: [2],
#  4: [0, 5, 6],
#  5: [4],
#  6: [4, 7],
#  7: [6]}

# %%
nx.draw_networkx(graph_data.G, graph_data.embed)

# %%
is_planar, embed = nx.check_planarity(graph_data.G)

# %%
embed.get_data()
# Out:
# {0: [1, 7, 6, 2],
#  1: [0, 2, 3, 5, 7],
#  2: [1, 0, 4, 3],
#  3: [2, 4, 5, 1],
#  4: [3, 2, 6, 5],
#  5: [4, 6, 7, 1, 3],
#  6: [5, 4, 0, 7],
#  7: [6, 0, 1, 5]}
