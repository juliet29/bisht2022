# %%
import imports
imports.update_path()

from helpers import nx, ic
from copy import deepcopy

from simple_four_con import graph_data

from canonical_order_kant import KantCanonicalOrder

from rel2 import REL2

from edge_label import EdgeLabeling, EdgeColorings

from helpers_classes import CardinalDirections

# %%
co = KantCanonicalOrder(deepcopy(graph_data))
co.initialize_order()
co.finish_order()
# Out:
# ic| f"updating chords for  {node_index} to {num_chords}": 'updating chords for  5 to 1'
# ic| f"{node_index} has no more chords": '5 has no more chords'
# ic| f"updating chords for  {node_index} to {num_chords}": 'updating chords for  7 to 1'
# ic| f"{node_index} has no more chords": '7 has no more chords'
# ic| f"ISSUE  FINDING UNMARKED CYCLE when vk = {self.vk}": 'ISSUE  FINDING UNMARKED CYCLE when vk = 2'
# ic| "Since vk=2, lack of unmarked cycle is not a problem, graph has been sufficiently ordered.": ('Since vk=2, lack of unmarked cycle is not a problem, graph has been '
#                                                                                                   'sufficiently ordered.')
# completed order - vk == 1

# %%
co.rel_helper
# Out:
# {7: {'unordered_boundary': [0, 1, 3, 4, 6], 'ordered_boundary': []},
#  6: {'unordered_boundary': [0, 1, 3, 5, 6], 'ordered_boundary': []},
#  5: {'unordered_boundary': [0, 1, 5, 6], 'ordered_boundary': []},
#  4: {'unordered_boundary': [0, 1, 7, 6], 'ordered_boundary': [2, 3, 4]},
#  3: {'unordered_boundary': [0, 7, 6], 'ordered_boundary': [2, 3, 5, 4]},
#  2: {'unordered_boundary': [], 'ordered_boundary': [1, 2, 4, 5]}}

# %% [markdown]
# ### base edge approach

# %%
re = REL2(co)
re.step_order_base_edge()
re.plot_graph()
# Out:
# ic| edges: [(5, 4)]
# ic| edges: [(3, 4)]

# %%
re = REL2(co)
re.step_order_base_edge()
re.plot_graph()
# Out:
# ic| edges: [(5, 4)]
# ic| edges: [(3, 4)]

# %%
re.step_order_base_edge()
re.plot_graph()
# Out:
# ic| edges: [(5, 4), (5, 3)]
# ic| edges: [(3, 4), (1, 3)]

# %%
re.step_order_base_edge()
re.plot_graph()
# Out:
# ic| edges: [(5, 4), (5, 3), (6, 5)]
# ic| edges: [(3, 4), (1, 3), (1, 5), (7, 5)]

# %%
re.step_order_base_edge()
re.plot_graph()
# Out:
# ic| edges: [(5, 4), (5, 3), (6, 5), (7, 1)]
# ic| edges: [(3, 4), (1, 3), (1, 5), (7, 5), (0, 1)]

# %%
re.step_order_base_edge()
re.plot_graph()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 re.step_order_base_edge()
#       2 re.plot_graph()
#
# File ~/_UILCode/gqe-phd/bisht2022/notebooks/rel/../../scripts/rel/rel2.py:31, in REL2.step_order_base_edge(self)
#      30 def step_order_base_edge(self):
# ---> 31     self.RELBaseEdge.step_base_edge_connnections()
#
# File ~/_UILCode/gqe-phd/bisht2022/notebooks/rel/../../scripts/rel/rel_base_edge.py:12, in RELBaseEdge.step_base_edge_connnections(self)
#      11 def step_base_edge_connnections(self):
# ---> 12     self.create_incoming_edges()
#      13     self.find_base_edge()
#      14     self.assign_colors()
#
# File ~/_UILCode/gqe-phd/bisht2022/notebooks/rel/../../scripts/rel/rel_base_edge.py:22, in RELBaseEdge.create_incoming_edges(self)
#      19 self.curr_node = self.REL.get_node_index_by_order(self.curr_order)
#      20 self.valid_nbs = self.REL.find_valid_nbs(self.curr_order)
# ---> 22 assert len(self.valid_nbs) > 0, f"No valid nbs for {self.curr_node_index}"
#      24 self.edges = [(nb, self.curr_node) for nb in self.valid_nbs]
#
# AttributeError: 'RELBaseEdge' object has no attribute 'curr_node_index'

# %% [markdown]
# ### corner rel

# %%
# re = REL2(co)
re.RELCorners.order_all_corners()
# re.step_order_interior()
# re.plot_graph()

# %%
re.plot_graph()
# Out:
# ic| edges: [(5, 4), (5, 3), (6, 5), (7, 1), (1, 2), (3, 2), (6, 5), (6, 7)]
# ic| edges: [(3, 4), (1, 3), (1, 5), (7, 5), (0, 1), (0, 1), (0, 7), (3, 4), (5, 4)]

# %% [markdown]
# ### interior work

# %%
re.step_order_interior()
re.plot_graph()
# Out:
# ic| self.curr_node_index: 7, self.curr_order: 2
# ic| edges: [(5, 4), (5, 3), (6, 5), (7, 1), (1, 2), (3, 2), (6, 5), (6, 7), (7, 1)]
# ic| edges: [(3, 4), (1, 3), (1, 5), (7, 5), (0, 1), (0, 1), (0, 7), (3, 4), (5, 4), (7, 5)]

# %%
re.step_order_interior()
re.plot_graph()
# Out:
# ic| self.curr_node_index: 1, self.curr_order: 3
# ic| edges: [(5, 4), (5, 3), (6, 5), (7, 1), (1, 2), (3, 2), (6, 5), (6, 7), (7, 1), (1, 2)]
# ic| edges: [(3, 4),
#             (1, 3),
#             (1, 5),
#             (7, 5),
#             (0, 1),
#             (0, 1),
#             (0, 7),
#             (3, 4),
#             (5, 4),
#             (7, 5),
#             (1, 5)]

# %%
re.step_order_interior()
re.plot_graph()
# Out:
# ic| self.curr_node_index: 5, self.curr_order: 4
# ic| edges: [(5, 4),
#             (5, 3),
#             (6, 5),
#             (7, 1),
#             (1, 2),
#             (3, 2),
#             (6, 5),
#             (6, 7),
#             (7, 1),
#             (1, 2),
#             (5, 3)]
# ic| edges: [(3, 4),
#             (1, 3),
#             (1, 5),
#             (7, 5),
#             (0, 1),
#             (0, 1),
#             (0, 7),
#             (3, 4),
#             (5, 4),
#             (7, 5),
#             (1, 5),
#             (5, 4)]
