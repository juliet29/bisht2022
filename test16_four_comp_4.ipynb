# %%
from helpers import * 
from processor import *
from four_complete import *
from graph_checks import *
from corner_implying_paths import *

import os
import pickle

# %%
bottom_data = get_saved_graph_data("BOTTOM")
side_data = get_saved_graph_data()

# %%
pos = plot_planar(side_data.G, side_data.embed)

# %%
f = FourComplete(copy.copy(side_data))

f.run_to_division()
f.paths
# Out:
# [[3, 8, 2, 7], [7, 6, 5, 4], [4, 0], [0, 3]]

# %%
side_data.G.nodes
# Out:
# NodeView((0, 1, 2, 3, 4, 5, 6, 7, 8))

# %%
f.boundary
# Out:
# [3, 8, 2, 7, 6, 5, 4, 0]

# %%
check_seperating_triangle(f.G)
# Out:
# ic| f"\n {len(l3_cycles)} three cycles ?= {m - n + 1}, where m={m}, n={n}": '
#                                                                               8 three cycles ?= 8, where m=16, n=9'
# False

# %% [markdown]
# ## check for cips

# %%
c = CornerImplyingPaths(side_data)
c.get_shortcuts()
c.shortcuts
# Out:
# ic| self.boundary: [3, 8, 2, 7, 6, 5, 4, 0]
# [(0, 7), (0, 2), (4, 6), (4, 7)]

# %%
c.get_cips()
c.cips
# Out:
# ic| 'A CIP', path: [0, 3, 8, 2]
# ic| 'A CIP', path: [4, 5, 6]
# [[0, 3, 8, 2], [4, 5, 6]]

# %%
pos = plot_planar(c.subgraph, side_data.embed)
