# %%
from helpers import * 
from processor import *
from four_complete import *
from graph_checks import *

import os
import pickle

# %%
G_st = st_graph() 
p = Processor(G_st)
p.augment()
p.fix_separating_triangles()

pos = plot_planar(p.data.G, p.data.embed)
# Out:
# ic| cut_vertices: [7, 0]
# ic| tri.target_edge: (2, 3)
# ic| 'neither same'
# ic| len(l3_cycles): 8, m: 16, n: 9, m - n + 1: 8

# %%
path = "saved_graphs/after_sep_tri"
final_path = os.path.join(path, "side_node", "data.p")
final_path
# Out:
# 'saved_graphs/after_sep_tri/side_node/data.p'

# %%
pickle.dump(p.data, open(final_path, "wb") )

# %%
a = pickle.load(open(final_path, "rb") )

# %%
pos = plot_planar(a.G, a.embed)

# %%
f = FourComplete(p.data)
f.run_to_division()

# %%
f.paths
# Out:
# [[0, 8, 3, 2], [2, 7, 6, 5], [5, 4], [4, 0]]

# %%
f.run_to_completion()

# %%
check_seperating_triangle(f.G)
# Out:
# ic| f"\n {len(l3_cycles)} three cycles ?= {m - n + 1}, where m={m}, n={n}": '
#                                                                               17 three cycles ?= 16, where m=28, n=13'
# False
